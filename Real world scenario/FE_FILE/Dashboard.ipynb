# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import streamlit as st
import warnings
warnings.filterwarnings("ignore")
import logging
logging.getLogger("streamlit").setLevel(logging.ERROR)

# %%
emp_data=pd.read_csv("df_fe.csv")
emp_data.drop(columns='Unnamed: 0',inplace=True)
emp_data
# Out:
#    first_name last_name                  email   join_date   salary  \
# 0        Yuki    Tanaka     yuki34@outlook.com  2021-10-09      NaN
# 1         Wei     Singh          wei@gmail.com  2021-10-09      NaN
# 2        Olga     Kumar    unknown@no_mail.com  2022-11-02  52872.0
# 3        Sara     Patel       sara78@yahoo.com  2021-06-25  78655.0
# 4        Luis     Kumar         luis@gmail.com  2023-07-22  62016.0
# 5      Fatima    Garcia       fatima@yahoo.com  2020-01-08      NaN
# 6     Michael     Kumar  michael43@outlook.com  2024-11-05  87764.0
# 7       Priya    Garcia        priya@yahoo.com         NaN  37084.0
# 8         Wei      Chen         wei4@gmail.com  2022-11-09      NaN
# 9     Michael    Tanaka  michael41@outlook.com  2021-06-27  58479.0
# 10       Olga    Garcia     olga25@outlook.com  2022-04-16  75692.0
# 11     Fatima     Patel   fatima27@outlook.com  2023-03-11  56612.0
# 12       Yuki      Chen       yuki95@yahoo.com  2022-06-23      NaN
# 13       Sara    Garcia         sara@yahoo.com         NaN  70583.0
# 14       Anil     Brown       anil52@yahoo.com         NaN      NaN
# 15       Sara     Singh     sara97@outlook.com  2024-06-29      NaN
# 16       Olga     Brown       olga@outlook.com  2023-01-27      NaN
# 17      Priya       Lee    priya54@outlook.com  2022-04-14  60534.0
# 18       John    Tanaka       john@outlook.com  2022-02-18  49569.0
# 19       Anil      Chen     anil11@outlook.com  2024-04-07  79283.0
# 20       Olga     Smith        olga4@yahoo.com         NaN      NaN
# 21       Yuki     Smith         yuki@yahoo.com         NaN  54596.0
# 22       Luis   Ivanova     luis54@outlook.com  2023-09-16      NaN
# 23       Yuki   Ivanova       yuki42@yahoo.com  2022-09-17      NaN
# 24       Luis     Singh     luis90@outlook.com  2022-12-23      NaN
# 25      Priya     Kumar      priya13@yahoo.com  2022-09-18      NaN
# 26    Michael     Singh    michael44@yahoo.com  2020-07-29  48634.0
# 27       Anil    Tanaka       anil59@gmail.com  2022-08-20      NaN
# 28       John    Garcia       john36@yahoo.com  2023-03-26      NaN
# 29       Anil    Garcia       anil42@gmail.com         NaN  32404.0
# 30       Anil     Smith       anil@outlook.com         NaN  48876.0
# 31       Anil     Kumar       anil18@gmail.com  2022-07-24      NaN
# 32       Anil     Patel     anil49@outlook.com  2023-01-08      NaN
# 33       Anil       Lee         anil@yahoo.com  2022-12-13  39447.0
# 34        Wei     Kumar      wei13@outlook.com  2020-07-04      NaN
# 35       Yuki     Patel     yuki31@outlook.com  2020-12-14  87071.0
# 36       Yuki     Kumar       yuki53@gmail.com         NaN      NaN
# 37    Michael     Patel    michael46@yahoo.com  2023-01-11  37204.0
# 38       Luis     Smith       luis96@gmail.com  2020-12-22  78609.0
#
#               remarks   sales  time_productive  increment_percentage  \
# 0       Good employee  4133.0             85.0                    12
# 1       Good employee  3138.0              NaN                    10
# 2   Needs improvement     NaN              NaN                     3
# 3             unknown  2915.0              NaN                    10
# 4       Good employee  4641.0             92.0                    12
# 5             unknown  2261.0              NaN                    10
# 6             unknown     NaN              NaN                     3
# 7       Good employee  2588.0            168.0                    10
# 8   Needs improvement  1263.0            157.0                     8
# 9             unknown  1291.0             85.0                     8
# 10            unknown   921.0             91.0                     8
# 11            unknown  3059.0             87.0                    10
# 12            unknown  4656.0            106.0                    12
# 13            unknown  4450.0             56.0                    12
# 14      Good employee  2352.0            110.0                    10
# 15            unknown     NaN             57.0                     3
# 16  Needs improvement  3283.0            135.0                    10
# 17            unknown     NaN             51.0                     3
# 18            unknown  2262.0            115.0                    10
# 19      Good employee     NaN            167.0                     3
# 20      Good employee  1168.0              NaN                     8
# 21      Good employee  2265.0              NaN                    10
# 22      Good employee     NaN             71.0                     3
# 23      Good employee  3737.0            149.0                     3
# 24  Needs improvement     NaN              NaN                     3
# 25  Needs improvement  1090.0              NaN                     8
# 26      Good employee  1137.0             59.0                     8
# 27            unknown  1221.0              NaN                     8
# 28            unknown     NaN              NaN                     3
# 29  Needs improvement  3362.0             70.0                    10
# 30      Good employee  1699.0             70.0                     3
# 31  Needs improvement     NaN            139.0                     3
# 32  Needs improvement  1736.0              NaN                     3
# 33      Good employee     NaN             90.0                     3
# 34      Good employee  3520.0            142.0                     3
# 35            unknown   836.0            144.0                     8
# 36      Good employee  2827.0              NaN                    10
# 37            unknown  4665.0             83.0                    12
# 38  Needs improvement  3470.0              NaN                    10
#
#     final_incremented_salary termination_flag  experience_days  \
# 0                        NaN               No           1474.0
# 1                        NaN               No           1474.0
# 2                   54458.16               No           1085.0
# 3                   86520.50               No           1580.0
# 4                   69457.92               No            823.0
# 5                        NaN               No           2114.0
# 6                   90396.92               No            351.0
# 7                   40792.40               No              NaN
# 8                        NaN               No           1078.0
# 9                   63157.32               No           1578.0
# 10                  81747.36               No           1285.0
# 11                  62273.20               No            956.0
# 12                       NaN               No           1217.0
# 13                  79052.96               No              NaN
# 14                       NaN               No              NaN
# 15                       NaN               No            480.0
# 16                       NaN               No            999.0
# 17                  62350.02               No           1287.0
# 18                  54525.90               No           1342.0
# 19                  81661.49               No            563.0
# 20                       NaN               No              NaN
# 21                  60055.60               No              NaN
# 22                       NaN               No            767.0
# 23                       NaN               No           1131.0
# 24                       NaN               No           1034.0
# 25                       NaN               No           1130.0
# 26                  52524.72               No           1911.0
# 27                       NaN               No           1159.0
# 28                       NaN               No            941.0
# 29                  35644.40               No              NaN
# 30                  50342.28               No              NaN
# 31                       NaN               No           1186.0
# 32                       NaN               No           1018.0
# 33                  40630.41               No           1044.0
# 34                       NaN               No           1936.0
# 35                  94036.68               No           1773.0
# 36                       NaN               No              NaN
# 37                  41668.48               No           1015.0
# 38                  86469.90               No           1765.0
#
#     experience_years          exp_year_cln         promotion_hr_based
# 0                4.0   4.0 years 14.0 days         Promotion Pipeline
# 1                4.0   4.0 years 14.0 days         Promotion Pipeline
# 2                2.0  2.0 years 355.0 days  Not In Promotion Pipeline
# 3                4.0  4.0 years 120.0 days         Promotion Pipeline
# 4                2.0   2.0 years 93.0 days  Not In Promotion Pipeline
# 5                5.0  5.0 years 289.0 days         Promotion Pipeline
# 6                0.0  0.0 years 351.0 days  Not In Promotion Pipeline
# 7                NaN    nan years nan days  Not In Promotion Pipeline
# 8                2.0  2.0 years 348.0 days  Not In Promotion Pipeline
# 9                4.0  4.0 years 118.0 days  Not In Promotion Pipeline
# 10               3.0  3.0 years 190.0 days  Not In Promotion Pipeline
# 11               2.0  2.0 years 226.0 days  Not In Promotion Pipeline
# 12               3.0  3.0 years 122.0 days  Not In Promotion Pipeline
# 13               NaN    nan years nan days  Not In Promotion Pipeline
# 14               NaN    nan years nan days  Not In Promotion Pipeline
# 15               1.0  1.0 years 115.0 days  Not In Promotion Pipeline
# 16               2.0  2.0 years 269.0 days  Not In Promotion Pipeline
# 17               3.0  3.0 years 192.0 days  Not In Promotion Pipeline
# 18               3.0  3.0 years 247.0 days  Not In Promotion Pipeline
# 19               1.0  1.0 years 198.0 days  Not In Promotion Pipeline
# 20               NaN    nan years nan days  Not In Promotion Pipeline
# 21               NaN    nan years nan days  Not In Promotion Pipeline
# 22               2.0   2.0 years 37.0 days  Not In Promotion Pipeline
# 23               3.0   3.0 years 36.0 days  Not In Promotion Pipeline
# 24               2.0  2.0 years 304.0 days  Not In Promotion Pipeline
# 25               3.0   3.0 years 35.0 days  Not In Promotion Pipeline
# 26               5.0   5.0 years 86.0 days  Not In Promotion Pipeline
# 27               3.0   3.0 years 64.0 days  Not In Promotion Pipeline
# 28               2.0  2.0 years 211.0 days  Not In Promotion Pipeline
# 29               NaN    nan years nan days  Not In Promotion Pipeline
# 30               NaN    nan years nan days  Not In Promotion Pipeline
# 31               3.0   3.0 years 91.0 days  Not In Promotion Pipeline
# 32               2.0  2.0 years 288.0 days  Not In Promotion Pipeline
# 33               2.0  2.0 years 314.0 days  Not In Promotion Pipeline
# 34               5.0  5.0 years 111.0 days  Not In Promotion Pipeline
# 35               4.0  4.0 years 313.0 days  Not In Promotion Pipeline
# 36               NaN    nan years nan days  Not In Promotion Pipeline
# 37               2.0  2.0 years 285.0 days  Not In Promotion Pipeline
# 38               4.0  4.0 years 305.0 days         Promotion Pipeline

# %%
avg_increment = emp_data['increment_percentage'].mean()
avg_salary = emp_data['salary'].mean()
retention_rate = emp_data['termination_flag'].value_counts(normalize = True)['No']*100

# %%
# Streamlit Dashboard Title
st.title("Employee KPI Dashboard")
# Out:
# 2025-12-16 10:40:14.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:14.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:14.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
col1 , col2 , col3 = st.columns(3)
col1.metric("Average Salary", f"{avg_salary: ,.0f}")
col2.metric("Average Increment" , f"{avg_increment : .1f}%")
col3.metric("Retention Rate" , f"{retention_rate : .1f}%")
# Out:
# 2025-12-16 10:40:15.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:40:15.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#Filters
st.sidebar.header("Filters")
exp_range = st.sidebar.slider("Experience Years" , 
                              min_value = 0,
                              max_value = int(emp_data['experience_years'].max()) +1 ,
                              value = (0, int(emp_data['experience_years'].max())))
termination_filter = st.sidebar.selectbox('Termination Status' , ['All','Active','Terminated'])
# Out:
# 2025-12-16 10:43:45.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:45.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:46.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:46.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:46.003 Session state does not function when running a script without `streamlit run`
# 2025-12-16 10:43:46.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:46.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:43:46.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#Apply filter
filter_map = {'Active' :'No',
              'Terminated' : 'Yes',
              'All' : 'All'}

flag_value = filter_map[termination_filter]
mask = emp_data['experience_years'].between(exp_range[0],
                                      exp_range[1]) & np.where(flag_value == 'All' ,True, emp_data['termination_flag'] == flag_value)

filtered_df = emp_data[mask]

# %%
# Scatterplot

fig = px.scatter(
    filtered_df,
    x = 'experience_years',
    y = 'salary',
    color = 'promotion_hr_based',
    title = 'Salary Vs Experience By Promotion Status',
    labels = {'experience_years' : 'Experience (in Years)',
              'salary' : 'Salary',
              'promotion_hr_based' : 'Promotion Status'},
    color_discrete_map={'Promotion Pipeline' : '#1f77b4', 
                        'Not In Promotion Pipeline' : '#1ec94c'})


st.plotly_chart(fig , use_container_width= True)
# Out:
# 2025-12-16 10:44:47.372 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-12-16 10:44:47.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:44:47.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:44:47.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:44:47.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-16 10:44:47.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
